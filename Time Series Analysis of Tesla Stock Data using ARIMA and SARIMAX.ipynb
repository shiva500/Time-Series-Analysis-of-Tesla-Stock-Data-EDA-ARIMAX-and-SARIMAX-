# %%
##Lets install Data Reader
#!pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("TSLA")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-10  179.940002  185.100006  176.110001  184.509995  184.509995
# 2023-04-11  186.690002  189.190002  185.649994  186.789993  186.789993
# 2023-04-12  190.740005  191.580002  180.309998  180.539993  180.539993
# 2023-04-13  182.960007  186.500000  180.940002  185.899994  185.899994
# 2023-04-14  183.949997  186.279999  182.009995  185.000000  185.000000
#
#                Volume
# Date
# 2023-04-10  142154600
# 2023-04-11  115770900
# 2023-04-12  150256300
# 2023-04-13  112933000
# 2023-04-14   96306500

# %%
data.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['Volume'].plot(figsize=(16,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['High'].plot(figsize=(16,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['Volume'].plot(xlim = ['2020-01-01','2023-01-01'],figsize=(12,4))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['High'].plot(xlim = ['2020-01-01','2023-01-01'],ylim = [0,500],figsize=(12,4),c='green')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-03-31', '2023-04-03', '2023-04-04', '2023-04-05',
#                '2023-04-06', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14'],
#               dtype='datetime64[ns]', name='Date', length=3221, freq=None)

# %%
data.iloc[:4]
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000

# %%
index = data.loc['2020-01-01':'2023-05-01'].index
share_open = data.loc['2020-01-01':'2023-05-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2023-04-10    179.940002
# 2023-04-11    186.690002
# 2023-04-12    190.740005
# 2023-04-13    182.960007
# 2023-04-14    183.949997
# Name: Open, Length: 827, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate() #prevents overlapping
axis.plot(index,share_open)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3221 entries, 2010-06-29 to 2023-04-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3221 non-null   float64
#  1   High       3221 non-null   float64
#  2   Low        3221 non-null   float64
#  3   Close      3221 non-null   float64
#  4   Adj Close  3221 non-null   float64
#  5   Volume     3221 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 305.2 KB

# %%
data = data.reset_index()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3221 non-null   datetime64[ns]
#  1   Open       3221 non-null   float64
#  2   High       3221 non-null   float64
#  3   Low        3221 non-null   float64
#  4   Close      3221 non-null   float64
#  5   Adj Close  3221 non-null   float64
#  6   Volume     3221 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 176.3 KB

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3221 non-null   datetime64[ns]
#  1   Open       3221 non-null   float64
#  2   High       3221 non-null   float64
#  3   Low        3221 non-null   float64
#  4   Close      3221 non-null   float64
#  5   Adj Close  3221 non-null   float64
#  6   Volume     3221 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 176.3 KB

# %%
data.set_index('Date',inplace=True)

# %%
data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-03-31', '2023-04-03', '2023-04-04', '2023-04-05',
#                '2023-04-06', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14'],
#               dtype='datetime64[ns]', name='Date', length=3221, freq=None)

# %%
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 16, 19, 50, 0, 587885)

# %%
data.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
data.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
data.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
##quaterly
data.resample(rule='QS').max()['High'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
## Business End Frequency
data.resample(rule='BA').max()['High'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data.resample(rule='BQS').max()['High'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['Open'].resample(rule='QS').mean().plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
data['Open'].resample(rule='QS').mean().plot(kind='bar',figsize=(16,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
data['Open:30 days rolling'] = data['Open'].rolling(3).mean()

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 days rolling
# Date
# 2010-06-29                   NaN
# 2010-06-30                   NaN
# 2010-07-01              1.550889
# 2010-07-02              1.639778
# 2010-07-06              1.511111

# %%
data[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['Open:3 days expanding'] = data['Open'].expanding(min_periods = 1).mean()

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#             Open:30 days rolling  Open:3 days expanding
# Date
# 2010-06-29                   NaN               1.266667
# 2010-06-30                   NaN               1.493000
# 2010-07-01              1.550889               1.550889
# 2010-07-02              1.639778               1.546500
# 2010-07-06              1.511111               1.503867

# %%
data[['Open','Open:30 days rolling','Open:3 days expanding']].plot(figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#1 Simple Moving Average
#2 Cumulative Moving Average
#3 Exponential Weight Moving Average
#4 Moving AVerage (Formula)--ACF
#5 Autoregrassive Moving Average

# %%
data['Open'].plot(figsize=(12,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data['10 days rolling']=data['Open'].rolling(window=10,min_periods=1).mean()

# %%
data[['Open','10 days rolling']].plot(xlim=('2023-01-01','2023-05-01'),figsize=(12,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#Cumulative Moving Average
data['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
###Exponential Weighted Moving Average
###EWMA(t) = a * x(t) + (1-a) EWMA(t-1)
data['EMA_0.1'] = data['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
data[['Open','EMA_0.1']].plot(xlim=('2023-01-01','2023-05-01'),figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
 data[['Open','EMA_0.1']].plot(xlim=('2023-01-01','2023-05-01'),figsize=(12,5))

# %%
data['EWMA_0.3'] = data['Open'].ewm(span=5).mean()

# %%
 data[['Open','EWMA_0.3']].plot(xlim=('2023-01-01','2023-05-01'),figsize=(12,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#ARIMA AR + MA  ---forcasting(sales,Monthly)
#MA = U + chi1 * Et-1

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms
import pandas as pd

# %matplotlib inline

# %%
#Autoregression ----PACF plot
#Moving Average ---ACF
#Integrated ----Differentiating

# %%
df_airline=pd.read_csv('airline_passengers.csv')
df_airline.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                    112.0
# 1  1949-02                    118.0
# 2  1949-03                    132.0
# 3  1949-04                    129.0
# 4  1949-05                    121.0

# %%
df_airline.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    1
# dtype: int64

# %%
df_airline.tail()
# Out:
#                                                  Month  \
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 140                    508.0
# 141                    461.0
# 142                    390.0
# 143                    432.0
# 144                      NaN

# %%
df_airline.dropna(axis=0,inplace=True)

# %%
df_airline.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    0
# dtype: int64

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    object
#  1   Thousands of Passengers  144 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.4+ KB

# %%
df_airline['Month']=pd.to_datetime(df_airline['Month'])

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    datetime64[ns]
#  1   Thousands of Passengers  144 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.4 KB

# %%
df_airline.set_index('Month',inplace=True)

# %%
df_airline.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(df_airline['Thousands of Passengers'])
# Out:
# ADF Statistics: 0.8153688792060456
# p- value: 0.991880243437641
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Use Techniques Differencing
df_airline['Passengers First Difference']=df_airline['Thousands of Passengers']-df_airline['Thousands of Passengers'].shift(1)

# %%
adf_test(df_airline['Passengers First Difference'].dropna())
# Out:
# ADF Statistics: -2.8292668241699817
# p- value: 0.05421329028382789
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Use Techniques Differencing
df_airline['Passengers Second Difference']=df_airline['Passengers First Difference']-df_airline['Passengers First Difference'].shift(1)

# %%
adf_test(df_airline['Passengers Second Difference'].dropna())
# Out:
# ADF Statistics: -16.384231542468523
# p- value: 2.7328918500141235e-29
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
### 12 months 
## Use Techniques Differencing
df_airline['Passengers 12 Difference']=df_airline['Thousands of Passengers']-df_airline['Thousands of Passengers'].shift(12)

# %%
adf_test(df_airline['Passengers 12 Difference'].dropna())

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf = plot_acf(df_airline["Passengers Second Difference"].dropna())

# %%
acf12 = plot_acf(df_airline["Passengers 12 Difference"].dropna())
pacf12 = plot_pacf(df_airline["Passengers 12 Difference"].dropna())
# Out:
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
result = plot_pacf(df_airline["Passengers Second Difference"].dropna())

# %%
pacf12 = plot_pacf(df_airline["Passengers 12 Difference"].dropna())

# %%
from datetime import datetime,timedelta
train_dataset_end=datetime(1955,12,1)
test_dataset_end=datetime(1960,12,1)
train_data=df_airline[:train_dataset_end]
test_data=df_airline[train_dataset_end+timedelta(days=1):test_dataset_end]
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
test_data
# Out:
#             Thousands of Passengers  Passengers First Difference  \
# Month
# 1956-01-01                    284.0                          6.0
# 1956-02-01                    277.0                         -7.0
# 1956-03-01                    317.0                         40.0
# 1956-04-01                    313.0                         -4.0
# 1956-05-01                    318.0                          5.0
# 1956-06-01                    374.0                         56.0
# 1956-07-01                    413.0                         39.0
# 1956-08-01                    405.0                         -8.0
# 1956-09-01                    355.0                        -50.0
# 1956-10-01                    306.0                        -49.0
# 1956-11-01                    271.0                        -35.0
# 1956-12-01                    306.0                         35.0
# 1957-01-01                    315.0                          9.0
# ...

# %%
## create a ARIMA model
from statsmodels.tsa.arima.model import ARIMA
train_data
# Out:
#             Thousands of Passengers  Passengers First Difference  \
# Month
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          6.0
# 1949-03-01                    132.0                         14.0
# 1949-04-01                    129.0                         -3.0
# 1949-05-01                    121.0                         -8.0
# ...                             ...                          ...
# 1955-08-01                    347.0                        -17.0
# 1955-09-01                    312.0                        -35.0
# 1955-10-01                    274.0                        -38.0
# 1955-11-01                    237.0                        -37.0
# 1955-12-01                    278.0                         41.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1949-01-01                           NaN                       NaN
# ...

# %%
model_ARIMA=ARIMA(train_data['Thousands of Passengers'],order=(0,2,0))
# Out:
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_Arima_fit=model_ARIMA.fit()

# %%
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ...
# Dep. Variable:     Thousands of Passengers   No. Observations:                   84
# Model:                      ARIMA(0, 2, 0)   Log Likelihood                -385.792
# Date:                     Sun, 16 Apr 2023   AIC                            773.584
# Time:                             21:27:52   BIC                            775.991
# Sample:                         01-01-1949   HQIC                           774.550
#                               - 12-01-1955
# Covariance Type:                       opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       714.5858    102.414      6.977      0.000     513.858     915.313
# ...
# Ljung-Box (L1) (Q):                   4.59   Jarque-Bera (JB):                 1.74
# ...

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred=model_Arima_fit.predict(start=pred_start_date,end=pred_end_date)
residuals=test_data['Thousands of Passengers']-pred

# %%
pred
# Out:
# 1956-01-01     319.0
# 1956-02-01     360.0
# 1956-03-01     401.0
# 1956-04-01     442.0
# 1956-05-01     483.0
# 1956-06-01     524.0
# 1956-07-01     565.0
# 1956-08-01     606.0
# 1956-09-01     647.0
# 1956-10-01     688.0
# 1956-11-01     729.0
# 1956-12-01     770.0
# 1957-01-01     811.0
# 1957-02-01     852.0
# 1957-03-01     893.0
# 1957-04-01     934.0
# 1957-05-01     975.0
# 1957-06-01    1016.0
# 1957-07-01    1057.0
# 1957-08-01    1098.0
# 1957-09-01    1139.0
# 1957-10-01    1180.0
# 1957-11-01    1221.0
# 1957-12-01    1262.0
# 1958-01-01    1303.0
# 1958-02-01    1344.0
# 1958-03-01    1385.0
# 1958-04-01    1426.0
# 1958-05-01    1467.0
# 1958-06-01    1508.0
# 1958-07-01    1549.0
# 1958-08-01    1590.0
# 1958-09-01    1631.0
# 1958-10-01    1672.0
# 1958-11-01    1713.0
# 1958-12-01    1754.0
# 1959-01-01    1795.0
# 1959-02-01    1836.0
# 1959-03-01    1877.0
# 1959-04-01    1918.0
# 1959-05-01    1959.0
# 1959-06-01    2000.0
# 1959-07-01    2041.0
# ...

# %%
residuals
# Out:
# Month
# 1956-01-01     -35.0
# 1956-02-01     -83.0
# 1956-03-01     -84.0
# 1956-04-01    -129.0
# 1956-05-01    -165.0
# 1956-06-01    -150.0
# 1956-07-01    -152.0
# 1956-08-01    -201.0
# 1956-09-01    -292.0
# 1956-10-01    -382.0
# 1956-11-01    -458.0
# 1956-12-01    -464.0
# 1957-01-01    -496.0
# 1957-02-01    -551.0
# 1957-03-01    -537.0
# 1957-04-01    -586.0
# 1957-05-01    -620.0
# 1957-06-01    -594.0
# 1957-07-01    -592.0
# 1957-08-01    -631.0
# 1957-09-01    -735.0
# 1957-10-01    -833.0
# 1957-11-01    -916.0
# 1957-12-01    -926.0
# 1958-01-01    -963.0
# 1958-02-01   -1026.0
# 1958-03-01   -1023.0
# 1958-04-01   -1078.0
# 1958-05-01   -1104.0
# 1958-06-01   -1073.0
# 1958-07-01   -1058.0
# 1958-08-01   -1085.0
# 1958-09-01   -1227.0
# 1958-10-01   -1313.0
# 1958-11-01   -1403.0
# 1958-12-01   -1417.0
# 1959-01-01   -1435.0
# 1959-02-01   -1494.0
# 1959-03-01   -1471.0
# 1959-04-01   -1522.0
# 1959-05-01   -1539.0
# 1959-06-01   -1528.0
# 1959-07-01   -1493.0
# ...

# %%
model_Arima_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
test_data['Predicted_ARIMA']=pred
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_9404\95659616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA']=pred

# %%
test_data[['Thousands of Passengers','Predicted_ARIMA']].plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
acf12 = plot_acf(df_airline["Passengers 12 Difference"].dropna())
pacf12 = plot_pacf(df_airline["Passengers 12 Difference"].dropna())
# Out:
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
## create a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMA=SARIMAX(train_data['Thousands of Passengers'],order=(3,0,5),seasonal_order=(0,1,0,12))
# Out:
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_SARIMA_fit=model_SARIMA.fit()
# Out:
# D:\DA with python\Anaconda\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_SARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:             Thousands of Passengers   No. Observations:                   84
# Model:             SARIMAX(3, 0, 5)x(0, 1, [], 12)   Log Likelihood                -265.241
# Date:                             Sun, 16 Apr 2023   AIC                            548.481
# Time:                                     21:30:56   BIC                            568.971
# Sample:                                 01-01-1949   HQIC                           556.638
#                                       - 12-01-1955
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5997      0.938      0.639      0.523      -1.239       2.439
# ...

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred_Sarima=model_SARIMA_fit.predict(start=datetime(1956,6,6),end=datetime(1960,12,1))
residuals=test_data['Thousands of Passengers']-pred_Sarima

# %%
model_SARIMA_fit.resid.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
model_SARIMA_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
test_data['Predicted_SARIMA']=pred_Sarima
# Out:
# C:\Users\samsung\AppData\Local\Temp\ipykernel_9404\1367177785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_SARIMA']=pred_Sarima

# %%
test_data[['Thousands of Passengers','Predicted_SARIMA','Predicted_ARIMA']].plot()
# Out:
# <AxesSubplot: xlabel='Month'>
